# %%
import pygfx as gfx
from microcity.terrain import make_terrain_mesh

# %%
mesh = make_terrain_mesh()

# %%
gfx.show(mesh)
# Out:
# RFBOutputContext()
# JupyterWgpuCanvas()

# %%
g = mesh.geometry

# %%
b = g.indices

# %%
b.data[100]
# Out:
# array([  50, 1074,   51], dtype=uint32)
